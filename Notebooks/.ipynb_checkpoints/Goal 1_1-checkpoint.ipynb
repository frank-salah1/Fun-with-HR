# %%
#import libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from Functions import *

# %%
#read in final dataset
file = '..\Data\Final_Data.csv'
df = pd.read_csv(file, index_col=8)
df.head()
# Out:
#                EmployeeID  Age Attrition     BusinessTravel  \
# EmployeeCount
# 1                       1   51        No      Travel_Rarely
# 1                       2   31       Yes  Travel_Frequently
# 1                       3   32        No  Travel_Frequently
# 1                       4   38        No         Non-Travel
# 1                       5   32        No      Travel_Rarely
#
#                            Department  DistanceFromHome  Education  \
# EmployeeCount
# 1                               Sales                 6          2
# 1              Research & Development                10          1
# 1              Research & Development                17          4
# 1              Research & Development                 2          5
# 1              Research & Development                10          1
#
#               EducationField  Gender  JobLevel  ... Over18 PercentSalaryHike  \
# EmployeeCount                                   ...
# ...

# %%
sns.lmplot(x = 'Age', y = 'YearsAtCompany', data = df, ci = 0)
plt.draw()

# %%
#create logistic regression, input GDP, output is_top20
X = df[['Age']]
y = df.YearsAtCompany
crossval = lin_reg(X, y, cv=10)
crossval
# Out:
# {'fit_time': array([0.01280928, 0.0084343 , 0.00799489, 0.00478077, 0.00793457,
#         0.        , 0.        , 0.01563644, 0.0158844 , 0.        ]),
#  'score_time': array([0.        , 0.        , 0.        , 0.        , 0.00011778,
#         0.        , 0.        , 0.        , 0.        , 0.        ]),
#  'estimator': (LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression()),
#  'test_score': array([0.08863067, 0.12819773, 0.05360594, 0.08509073, 0.11841973,
#         0.0808323 , 0.0735319 , 0.11658501, 0.11007975, 0.08694456]),
#  'train_score': array([0.09771288, 0.09272143, 0.10027542, 0.09828421, 0.09425845,
#         0.09809001, 0.09959882, 0.09460671, 0.09543406, 0.09800559])}

# %%
estimator = crossval['estimator'][2]

# %%
estimator.predict(df[['Age']])
# Out:
# array([10.05049532,  5.77199453,  5.98591957, ...,  5.34414445,
#         4.48844429,  8.12516997])

# %%
df[['YearsAtCompany']]
# Out:
#                YearsAtCompany
# EmployeeCount
# 1                           1
# 1                           5
# 1                           5
# 1                           8
# 1                           6
# ...                       ...
# 1                           6
# 1                           3
# 1                           3
# 1                           4
# 1                           9
#
# [4382 rows x 1 columns]
