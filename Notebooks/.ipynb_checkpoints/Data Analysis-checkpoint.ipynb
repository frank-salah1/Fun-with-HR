# %%
#import libraries
import pandas as pd
import seaborn as sns

# %%
#read in NFL combine  file
file = '..\\Data\\general_data.csv'
df = pd.read_csv(file, index_col=0)
df.head()
# Out:
#     Attrition     BusinessTravel              Department  DistanceFromHome  \
# Age
# 51         No      Travel_Rarely                   Sales                 6
# 31        Yes  Travel_Frequently  Research & Development                10
# 32         No  Travel_Frequently  Research & Development                17
# 38         No         Non-Travel  Research & Development                 2
# 32         No      Travel_Rarely  Research & Development                10
#
#      Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# Age
# 51           2  Life Sciences              1           1  Female         1
# 31           1  Life Sciences              1           2  Female         1
# 32           4          Other              1           3    Male         4
# 38           5  Life Sciences              1           4    Male         3
# 32           1        Medical              1           5    Male         1
#
# ...

# %%
df.describe(include='all')
# Out:
#        Attrition BusinessTravel              Department  DistanceFromHome  \
# count       4410           4410                    4410       4410.000000
# unique         2              3                       3               NaN
# top           No  Travel_Rarely  Research & Development               NaN
# freq        3699           3129                    2883               NaN
# mean         NaN            NaN                     NaN          9.192517
# std          NaN            NaN                     NaN          8.105026
# min          NaN            NaN                     NaN          1.000000
# 25%          NaN            NaN                     NaN          2.000000
# 50%          NaN            NaN                     NaN          7.000000
# 75%          NaN            NaN                     NaN         14.000000
# max          NaN            NaN                     NaN         29.000000
#
#           Education EducationField  EmployeeCount   EmployeeID Gender  \
# ...

# %%
#look at datatypes
df.dtypes
# Out:
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeID                   int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
#check to see if there are any null values
df.isnull().sum()
# Out:
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
#drop rows with na value
df.dropna(inplace=True)

# %%
#perform a quick comparison of all data to understand general patterns
sns.pairplot(df)

# %%
#see if there are any outliers for monthly 
sns.boxplot(data=df, x='MonthlyIncome')

# %%
#see if there are any outliers for working years 
sns.boxplot(data=df, x='TotalWorkingYears')

# %%
#save new dataset to csv
file = '..\\Data\\NFL_Combine_WR.csv'
df_wr.to_csv(file)
