# %%
#install and import libraries
import sys

# !conda install --yes --prefix {sys.prefix} -c districtdatalabs yellowbrick
from yellowbrick.cluster import KElbowVisualizer

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import numpy as np

import pandas as pd

from Functions import *
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
# C:\Users\frank\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#read in NFL combine WR file
file = '..\\Data\\NFL_Combine_WR.csv'
df = pd.read_csv(file, index_col=0)
df.head()
# Out:
#                   Ht   Wt  Forty  Vertical
# Player
# Plaxico Burress   77  231   4.59      33.0
# Kwame Cavil       74  208   4.54      39.5
# Chris Cole        72  191   4.37      37.5
# Chris Coleman     72  211   4.61      32.5
# Laveranues Coles  71  192   4.41      34.0

# %%
#scale data using standard scaler
sc = StandardScaler()
sc.fit(df[['Ht', 'Wt', 'Forty', 'Vertical']])
df_std = sc.transform(df[['Ht', 'Wt', 'Forty', 'Vertical']])
df_std
# Out:
# array([[ 1.90045383,  1.95399987,  0.75684299, -0.7217416 ],
#        [ 0.56285671,  0.4017009 ,  0.25588362,  1.37962685],
#        [-0.32887471, -0.74565052, -1.44737824,  0.73305195],
#        ...,
#        [ 1.45458812,  1.27908727,  1.55837798, -0.39845414],
#        [ 0.56285671, -0.34070296,  0.35607549,  0.57140822],
#        [ 1.00872242,  0.87413971,  0.15569175, -0.56009787]])

# %%
#determine kmeans groups
kmeans_groups(min=2, max=30, df = df_std)
# Out:
# C:\Users\frank\anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:182: YellowbrickWarning: No "knee" or "elbow point" detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\frank\anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# C:\Users\frank\anaconda3\lib\site-packages\yellowbrick\cluster\elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %%
#determine kmeans groups
kmeans_groups(min=2, max=30, df = df_std, metric = 'silhouette')

# %%
#10 groupings were deemed appropriate based on the score above, however there is a different result,so it may be slightly different
k_means, y_hat = kmeans_clust (n_clusters=10, df=df_std)


df['Predict_AllSS'] = y_hat

cl_centers = k_means.cluster_centers_
cl_centers
# Out:
# array([[ 0.01742876, -0.24306998,  0.49614957,  0.32188052],
#        [-0.23270759, -0.18719343,  1.64678258, -0.85169048],
#        [-0.97011977, -0.98831573, -1.21322195,  0.85110635],
#        [ 0.5958838 ,  0.61334015, -0.6643973 ,  0.19423952],
#        [-0.61260743, -0.58919351, -0.60181954, -0.61642826],
#        [ 0.47247853,  0.42815017,  0.05685382, -1.11711342],
#        [ 1.12018884,  1.34320397,  0.55311951,  0.6010429 ],
#        [ 0.34818063,  0.35545688, -0.64213244,  1.61909904],
#        [ 1.44468   ,  1.35557737,  1.0440597 , -0.9085299 ],
#        [-1.54615886, -1.28129544,  0.2654257 , -0.64220262]])

# %%
df
# Out:
#                    Ht   Wt  Forty  Vertical  Predict_AllSS
# Player
# Plaxico Burress    77  231   4.59      33.0              8
# Kwame Cavil        74  208   4.54      39.5              7
# Chris Cole         72  191   4.37      37.5              2
# Chris Coleman      72  211   4.61      32.5              1
# Laveranues Coles   71  192   4.41      34.0              4
# ...                ..  ...    ...       ...            ...
# Jester Weah        74  211   4.43      38.0              3
# Karaun White       73  206   4.52      33.5              5
# Jake Wieneke       76  221   4.67      34.0              8
# Cedrick Wilson-02  74  197   4.55      37.0              0
# Javon Wims         75  215   4.53      33.5              5
#
# [686 rows x 5 columns]

# %%
LABEL_COLOR_MAP = {0 : 'red',
                  1 : 'yellow',
                   2: 'blue',
                  3: 'green',
                   4:'orange',
                   5: 'black',
                   6: 'purple',
                   7: 'pink',
                   8: 'grey',
                   9: 'cyan' 
                }


label_color = [LABEL_COLOR_MAP[l] for l in df.Predict_AllSS]

graph_display(X = df.Forty, y= df.Vertical, labelX='Forty', labely='Vertical', pred=label_color)

# %%
LABEL_COLOR_MAP = {0 : 'red',
                  1 : 'yellow',
                   2: 'blue',
                  3: 'green',
                   4:'orange',
                   5: 'black',
                   6: 'purple',
                   7: 'pink',
                   8: 'grey',
                   9: 'cyan' 
                }


label_color = [LABEL_COLOR_MAP[l] for l in df.Predict_AllSS]

graph_display(X = df.Forty, y= df.Ht, labelX='Forty', labely='Ht', pred=label_color)

# %%
LABEL_COLOR_MAP = {0 : 'red',
                  1 : 'yellow',
                   2: 'blue',
                  3: 'green',
                   4:'orange',
                   5: 'black',
                   6: 'purple',
                   7: 'pink',
                   8: 'grey',
                   9: 'cyan' 
                }


label_color = [LABEL_COLOR_MAP[l] for l in df.Predict_AllSS]

graph_display(X = df.Forty, y= df.Wt, labelX='Forty', labely='Wt', pred=label_color)

# %%
LABEL_COLOR_MAP = {0 : 'red',
                  1 : 'yellow',
                   2: 'blue',
                  3: 'green',
                   4:'orange',
                   5: 'black',
                   6: 'purple',
                   7: 'pink',
                   8: 'grey',
                   9: 'cyan' 
                }


label_color = [LABEL_COLOR_MAP[l] for l in df.Predict_AllSS]

graph_display(X = df.Ht, y= df.Wt, labelX='Ht', labely='Wt', pred=label_color)

# %%
LABEL_COLOR_MAP = {0 : 'red',
                  1 : 'yellow',
                   2: 'blue',
                  3: 'green',
                   4:'orange',
                   5: 'black',
                   6: 'purple',
                   7: 'pink',
                   8: 'grey',
                   9: 'cyan' 
                }


label_color = [LABEL_COLOR_MAP[l] for l in df.Predict_AllSS]

graph_display(X = df.Vertical, y= df.Wt, labelX='Vertical', labely='Wt', pred=label_color)

# %%
LABEL_COLOR_MAP = {0 : 'red',
                  1 : 'yellow',
                   2: 'blue',
                  3: 'green',
                   4:'orange',
                   5: 'black',
                   6: 'purple',
                   7: 'pink',
                   8: 'grey',
                   9: 'cyan' 
                }


label_color = [LABEL_COLOR_MAP[l] for l in df.Predict_AllSS]

graph_display(X = df.Vertical, y= df.Ht, labelX='Vertical', labely='Ht', pred=label_color)
